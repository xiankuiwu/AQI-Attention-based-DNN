# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams['font.family'] = 'Times New Roman'

# %%
df = pd.read_csv('beijing.csv',encoding = 'gb2312')

# %%
df.head()
# Out:
#            日期  AQI  质量等级  PM2.5  PM10  NO2  SO2   CO  O3_8h
# 0  2013-12-02  142  轻度污染    109   138   88   61  2.6     11
# 1  2013-12-03   86     良     64    86   54   38  1.6     45
# 2  2013-12-04  109  轻度污染     82   101   62   42  2.0     23
# 3  2013-12-05   56     良     39    56   38   30  1.2     52
# 4  2013-12-06  169  中度污染    128   162   78   48  2.5     15

# %%
time=df.iloc[0:200,0]

# %%
print(time)
# Out:
# 0      2013-12-02
# 1      2013-12-03
# 2      2013-12-04
# 3      2013-12-05
# 4      2013-12-06
#           ...
# 195    2014-06-15
# 196    2014-06-16
# 197    2014-06-17
# 198    2014-06-18
# 199    2014-06-19
# Name: 日期, Length: 200, dtype: object

# %%
aqi_data = df.iloc[0:200,1]

# %%
print(aqi_data)
# Out:
# 0      142
# 1       86
# 2      109
# 3       56
# 4      169
#       ...
# 195    176
# 196    165
# 197    116
# 198    115
# 199    158
# Name: AQI, Length: 200, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# 假设你的数据
time_numeric = np.arange(len(time)) + 1
data = np.column_stack((time_numeric, aqi_data))
alpha = 0.05

def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat

smoothed_aqi_data = exponential_smoothing(alpha, data[:, 1])

# 绘制原始AQI值和平滑后的AQI值
plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='AQI')
plt.plot(data[:, 0], smoothed_aqi_data, label=f'AQI_ETS (alpha={alpha})', linestyle='dashed')

# 在左上角添加 "#1"
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')

plt.xlabel('Time')
plt.ylabel('AQI')
plt.legend()
plt.savefig('BA.pdf', bbox_inches='tight')
plt.show()

# %%
PM2_data = df.iloc[0:200,3]

# %%
print(PM2_data)
# Out:
# 0      109
# 1       64
# 2       82
# 3       39
# 4      128
#       ...
# 195    101
# 196    126
# 197     88
# 198     61
# 199    121
# Name: PM2.5, Length: 200, dtype: int64

# %%
time_numeric = np.arange(len(time)) + 1

# 合并时间和AQI值为二维数组
data = np.column_stack((time_numeric, PM2_data))

# 定义 alpha 值
alpha = 0.05

# 简单指数平滑函数
def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat

# 应用简单指数平滑
smoothed_PM2_data = exponential_smoothing(alpha, data[:, 1])

# 绘制原始AQI值和平滑后的AQI值
plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='PM2.5')
plt.plot(data[:, 0], smoothed_PM2_data, label=f'PM2.5_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
#plt.title('PM2.5')
plt.xlabel('Time')
plt.ylabel('PM2.5')
plt.legend()
plt.savefig('BM2.pdf', bbox_inches='tight')
plt.show()

# %%
PM10_data = df.iloc[0:200,4]

# %%
time_numeric = np.arange(len(time)) + 1

# 合并时间和AQI值为二维数组
data = np.column_stack((time_numeric, PM10_data))

# 定义 alpha 值
alpha = 0.05

# 简单指数平滑函数
def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat

# 应用简单指数平滑
smoothed_PM10_data = exponential_smoothing(alpha, data[:, 1])

# 绘制原始AQI值和平滑后的AQI值
plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='PM10')
plt.plot(data[:, 0], smoothed_PM10_data, label=f'PM10_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Time')
plt.ylabel('PM10')
plt.legend()
plt.savefig('BM1.pdf', bbox_inches='tight')
plt.show()

# %%
NO2_data = df.iloc[0:200,5]
time_numeric = np.arange(len(time)) + 1

data = np.column_stack((time_numeric, NO2_data))


alpha = 0.05

def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat

# 应用简单指数平滑
smoothed_NO2_data = exponential_smoothing(alpha, data[:, 1])

# 绘制原始AQI值和平滑后的AQI值
plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='NO2')
plt.plot(data[:, 0], smoothed_NO2_data, label=f'NO2_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Time')
plt.ylabel('NO2')
plt.legend()
plt.legend(loc='upper right')
plt.savefig('BN.pdf', bbox_inches='tight')
plt.show()

# %%
SO2_data = df.iloc[0:200,6]
time_numeric = np.arange(len(time)) + 1

data = np.column_stack((time_numeric, SO2_data))


alpha = 0.05

def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat


smoothed_SO2_data = exponential_smoothing(alpha, data[:, 1])


plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='SO2')
plt.plot(data[:, 0], smoothed_SO2_data, label=f'SO2_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Time')
plt.ylabel('SO2')
plt.legend()
plt.legend(loc='upper right')
plt.savefig('BS.pdf', bbox_inches='tight')
plt.show()

# %%
CO_data = df.iloc[0:200,7]
time_numeric = np.arange(len(time)) + 1

data = np.column_stack((time_numeric, CO_data))


alpha = 0.05

def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat


smoothed_CO_data = exponential_smoothing(alpha, data[:, 1])


plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='CO')
plt.plot(data[:, 0], smoothed_CO_data, label=f'CO_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Time')
plt.ylabel('CO')
plt.legend()
plt.legend(loc='upper right')
plt.savefig('BC.pdf', bbox_inches='tight')
plt.show()

# %%
O3_8h_data = df.iloc[0:200,8]
time_numeric = np.arange(len(time)) + 1

data = np.column_stack((time_numeric, O3_8h_data))


alpha = 0.05

def exponential_smoothing(alpha, s):
    s_hat = np.zeros_like(s)
    s_hat[0] = s[0]
    for t in range(1, len(s)):
        s_hat[t] = alpha * s[t] + (1 - alpha) * s_hat[t - 1]
    return s_hat


smoothed_O3_8h_data = exponential_smoothing(alpha, data[:, 1])


plt.figure(figsize=(6, 4))
plt.plot(data[:, 0], data[:, 1], label='O3_8h')
plt.plot(data[:, 0], smoothed_O3_8h_data, label=f'O3_8h_ETS (alpha={alpha})', linestyle='dashed')
plt.text(1, max(data[:, 1]), '#1', fontsize=12, verticalalignment='top', horizontalalignment='left')
plt.xlabel('Time')
plt.ylabel('O3_8h')
plt.legend()
plt.legend(loc='upper right')
plt.savefig('BO.pdf', bbox_inches='tight')
plt.show()
